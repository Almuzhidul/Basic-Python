# %% [markdown]
# <a href="https://colab.research.google.com/github/Almuzhidul/Basic-Python/blob/main/Membaca_File_Pada_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![WhatsApp Image 2023-01-10 at 08.33.44.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# #**Membaca File Pada Google Colab (part 1)**
# Pada bidang data terdapat beberapa jenis file. Diantaranya yang kita ketahui adalah CSV dan excel.
#
# Membaca data ini untuk kemudian diolah merupakan salah satu langkah awal dalam pengerjaan data. Maka dari itu pada code kali ini kita akan belajar cara membaca kedua jenis data tersebut dan mengubahnya kedalam dataframe.

# %% [markdown]
# ###**File Excel**

# %% [markdown]
# **Cara 1.**\
# Yaitu dengan cara mengupload data dari lokal sistem.

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-52d79a84-580e-4730-ad3f-376ad67f0bc9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52d79a84-580e-4730-ad3f-376ad67f0bc9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Kemudian tuliskan nama file ke dalam code\
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_excel("sampel.xlsx")
df.head(5)
# Out:
#    Sampel     A     B     C     D
# 0       1  11.0   9.4  12.5  13.2
# 1       2   9.6   9.6  11.5  13.2
# 2       3  10.8   9.6  10.5  13.5
# 3       4  10.5  10.8  10.5  15.0
# 4       5  11.5  10.5  11.8  14.6

# %% [markdown]
# **Cara 2.**\
# Yaitu dengan cara mengambil data dari google drive.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# Kemudian cari data yang diinginkan pada google drive dengan mengklik ikon foder pada bagian kiri\
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Setelah file yang diinginka didapatkan selanjutnya klik titik 3 pada file dan kemudian copy path dan paste pada code\
# ![image.png](data:image/png;base64,...)

# %%
df = pd.read_excel("/content/gdrive/MyDrive/sampel.xlsx")
df.head(5)
# Out:
#    Sampel     A     B     C     D
# 0       1  11.0   9.4  12.5  13.2
# 1       2   9.6   9.6  11.5  13.2
# 2       3  10.8   9.6  10.5  13.5
# 3       4  10.5  10.8  10.5  15.0
# 4       5  11.5  10.5  11.8  14.6

# %% [markdown]
# **Cara 3.**\
# Yaitu dengan cara menggunakan menu upload yang telah disediakan oleh google colab.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Jika sudah memilih file excel yang akan diupload maka file akan muncul pada ikon files disebelah kiri. Setelah muncul maka tinggal mengklik titik 3 pada file dan kemudian copy path/salin jalur dan paste pada code.\
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/sampel.xlsx")
df.head(5)
# Out:
#    Sampel     A     B     C     D
# 0       1  11.0   9.4  12.5  13.2
# 1       2   9.6   9.6  11.5  13.2
# 2       3  10.8   9.6  10.5  13.5
# 3       4  10.5  10.8  10.5  15.0
# 4       5  11.5  10.5  11.8  14.6

# %% [markdown]
# ###**CSV**
# Untuk membaca file csv terdapat 3 cara seperti yang ada pada cara membaca file excel sebelumnya. Hanya saja terdapat sedikit perbedaan pada codenya. Jika pada saat membaca file excel kita menggunakan ```read_excel``` maka pada file CSV kita menggunakan ```read_csv```

# %% [markdown]
# **Cara 1.**\
# Yaitu dengan cara mengupload data dari lokal sistem.

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28e7bbfb-cd63-40e8-be17-e43ffec7ce32" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28e7bbfb-cd63-40e8-be17-e43ffec7ce32">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("data penjualan toko (1).csv")
df.head(5)
# Out:
#    Toko  Departemen   Tanggal  Penjualan_Mingguan  ApakahLibur  Temperatur  \
# 0    45          90   5/13/11            22171.16        False       60.38
# 1    44          92   4/16/10            36509.64        False       50.39
# 2    12           8   8/26/11            41843.20        False       94.61
# 3    29          98   8/20/10                9.04        False       73.21
# 4     6          29  12/30/11             9146.12         True       46.80
#
#    Harga_BBM
# 0      4.066
# 1      2.915
# 2      3.740
# 3      2.796
# 4      3.129

# %% [markdown]
# **Cara 2.**\
# Yaitu dengan cara mengambil data dari google drive.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
df = pd.read_csv("/content/data penjualan toko.csv")
df.head(5)
# Out:
#    Toko  Departemen   Tanggal  Penjualan_Mingguan  ApakahLibur  Temperatur  \
# 0    45          90   5/13/11            22171.16        False       60.38
# 1    44          92   4/16/10            36509.64        False       50.39
# 2    12           8   8/26/11            41843.20        False       94.61
# 3    29          98   8/20/10                9.04        False       73.21
# 4     6          29  12/30/11             9146.12         True       46.80
#
#    Harga_BBM
# 0      4.066
# 1      2.915
# 2      3.740
# 3      2.796
# 4      3.129

# %% [markdown]
# **Cara 3.**\
# Yaitu dengan cara menggunakan menu upload yang telah disediakan oleh google colab.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/data penjualan toko.csv")
df.head(5)
# Out:
#    Toko  Departemen   Tanggal  Penjualan_Mingguan  ApakahLibur  Temperatur  \
# 0    45          90   5/13/11            22171.16        False       60.38
# 1    44          92   4/16/10            36509.64        False       50.39
# 2    12           8   8/26/11            41843.20        False       94.61
# 3    29          98   8/20/10                9.04        False       73.21
# 4     6          29  12/30/11             9146.12         True       46.80
#
#    Harga_BBM
# 0      4.066
# 1      2.915
# 2      3.740
# 3      2.796
# 4      3.129
